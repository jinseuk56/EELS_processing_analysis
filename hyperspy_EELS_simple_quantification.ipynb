# %%
# %matplotlib nbagg
import hyperspy.api as hys
import numpy as np
import tkinter.filedialog as tkf

# %%
hl = hys.load(tkf.askopenfilename(), signal_type = "EELS")
ll = hys.load(tkf.askopenfilename(), signal_type = "EELS")
print(hl)
print(ll)
# Out:
# <EELSSpectrum, title: 2_EELS Spectrum Image (high-loss), dimensions: (69, 69|2048)>
# <EELSSpectrum, title: 2_EELS Spectrum Image (low-loss), dimensions: (69, 69|2048)>

# %%
hl.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
hl.remove_background()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# ...
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
roi = hys.roi.SpanROI(left=630, right=670)
hl.plot()
roi.add_widget(hl, axes=["Energy loss"])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
hl_mn = hl.isig[roi].integrate1D(axis="Energy loss")
hl_mn.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
