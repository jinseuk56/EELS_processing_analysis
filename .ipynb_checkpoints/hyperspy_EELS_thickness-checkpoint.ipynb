# %%
# %matplotlib nbagg
import hyperspy.api as hys
import numpy as np
import tkinter.filedialog as tkf
# Out:
# WARNING:hyperspy_gui_traitsui:The nbAgg matplotlib backend is not supported by the installed traitsui version and the ETS toolkit has been set to null. To set the ETS toolkit independently from the matplotlib backend, set it before importing matplotlib. See http://hyperspy.readthedocs.io/en/stable/user_guide/getting_started.html for more information.
# WARNING:hyperspy_gui_traitsui:The traitsui GUI elements are not available.

# %%
hl = hys.load(tkf.askopenfilename(), signal_type = "EELS")
ll = hys.load(tkf.askopenfilename(), signal_type = "EELS")
print(hl)
print(ll)
# Out:
# <EELSSpectrum, title: 2_EELS Spectrum Image (high-loss), dimensions: (71, 71|2048)>
# <EELSSpectrum, title: 2_EELS Spectrum Image (low-loss), dimensions: (71, 71|2048)>

# %%
ll.align_zero_loss_peak(also_align=[hl])
# Out:
# Initial ZLP position statistics
# -------------------------------
# Summary statistics
# ------------------
# mean:	-0.631
# std:	0.0699
#
# min:	-0.85
# Q1:	-0.65
# median:	-0.65
# Q3:	-0.6
# max:	-0.4
# HBox(children=(IntProgress(value=0, max=5041), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5041), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5041), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5041), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5041), HTML(value='')))

# %%
thickness_map = ll.estimate_thickness(threshold=3.0)
thickness_map.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
